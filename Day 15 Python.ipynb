# %% [markdown]
# # Day 15

# %% [markdown]
# # Pandas Library 2nd Part

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df =pd.read_csv("https://media.githubusercontent.com/media/datablist/sample-csv-files/main/files/customers/customers-10000.csv")

# %%
df
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
df['City']
# Out:
# 0       Lake Jeffborough
# 1             Aaronville
# 2            East Jordan
# 3       East Kristintown
# 4            Andresmouth
#               ...
# 9995          Petersport
# 9996          Briggsport
# 9997      West Joyceport
# 9998      Camachochester
# 9999          Sparkstown
# Name: City, Length: 10000, dtype: object

# %%
a = df['City'][0:10]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
print(a)
# Out:
# 0      Lake Jeffborough
# 1            Aaronville
# 2           East Jordan
# 3      East Kristintown
# 4           Andresmouth
# 5    Lake Madelineburgh
# 6            West Ralph
# 7            Ambershire
# 8           Barrettview
# 9            New Rickey
# Name: City, dtype: object

# %%
l = ['swati','a2','a3','a4','a5','a6','a7','a8','a9','a10']

# %%
pd.Series(a, index = l)
# Out:
# swati    NaN
# a2       NaN
# a3       NaN
# a4       NaN
# a5       NaN
# a6       NaN
# a7       NaN
# a8       NaN
# a9       NaN
# a10      NaN
# Name: City, dtype: object

# %%
pd.Series(list(a), index = l)
# Out:
# swati      Lake Jeffborough
# a2               Aaronville
# a3              East Jordan
# a4         East Kristintown
# a5              Andresmouth
# a6       Lake Madelineburgh
# a7               West Ralph
# a8               Ambershire
# a9              Barrettview
# a10              New Rickey
# dtype: object

# %%
m1 = pd.Series([100,200,300,400,500],index = [1,2,3,4,5])

# %%
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2 = pd.Series([600,700,800,900,1000],index = [1,2,3,4,5])

# %%
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3 = pd.concat([m1,m2])

# %%
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1]
# Out:
# 1    100
# 1    600
# dtype: int64

# %%
m1*m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %%
m1+m2
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
df.head()
# Out:
#    Index      Customer Id First Name  Last Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather   Callahan              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina    Ferrell  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# ...

# %%
df.drop("Last Name", axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Index      Customer Id First Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# 0        915.112.1727      urangel@espinoza-francis.net        2020-08-26
# ...

# %%
df.head()
# Out:
#    Index      Customer Id First Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# 0        915.112.1727      urangel@espinoza-francis.net        2020-08-26
# ...

# %%
df.drop(3, inplace = True)

# %%
df
# Out:
#       Index      Customer Id First Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana               Irwin-Oneal
# 4         5  5820deAdCF23EFe   Kathleen              Carson-Burch
# 5         6  E1CDEaC63fDd5aA     Trevor              Maddox Group
# ...     ...              ...        ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa              Burns-Holden
#
#                     City                       Country                Phone 1  \
# 0       Lake Jeffborough                        Norway           043-797-5229
# ...

# %%
df.set_index("City",inplace = True)

# %%
df
# Out:
#                     Index      Customer Id First Name  \
# City
# Lake Jeffborough        1  EB54EF1154C3A78    Heather
# Aaronville              2  10dAcafEBbA5FcA   Kristina
# East Jordan             3  67DAB15Ebe4BE4a     Briana
# Andresmouth             5  5820deAdCF23EFe   Kathleen
# Lake Madelineburgh      6  E1CDEaC63fDd5aA     Trevor
# ...                   ...              ...        ...
# Petersport           9996  DD0caa06ebf217c     Meghan
# Briggsport           9997  C1C62ff90D0AfED   Jeremiah
# West Joyceport       9998  2EfAa6Fe435A7DA      Peggy
# Camachochester       9999  5dB06C3Fab5CCCb       Evan
# Sparkstown          10000  9903e8fF4D8Ff0F    Melissa
#
#                                      Company                       Country  \
# City
# Lake Jeffborough                Mosley-David                        Norway
# Aaronville          Horn, Shepard and Watson                       Andorra
# ...

# %%
df.head()
# Out:
#                     Index      Customer Id First Name  \
# City
# Lake Jeffborough        1  EB54EF1154C3A78    Heather
# Aaronville              2  10dAcafEBbA5FcA   Kristina
# East Jordan             3  67DAB15Ebe4BE4a     Briana
# Andresmouth             5  5820deAdCF23EFe   Kathleen
# Lake Madelineburgh      6  E1CDEaC63fDd5aA     Trevor
#
#                                      Company  Country                Phone 1  \
# City
# Lake Jeffborough                Mosley-David   Norway           043-797-5229
# Aaronville          Horn, Shepard and Watson  Andorra           932-062-1802
# East Jordan                      Irwin-Oneal    Nepal             8352752061
# Andresmouth                     Carson-Burch    Macao  001-184-153-9683x1497
# Lake Madelineburgh              Maddox Group  Senegal   +1-134-348-0265x9132
#
#                                Phone 2                             Email  \
# City
# Lake Jeffborough          915.112.1727      urangel@espinoza-francis.net
# ...

# %%
df.reset_index()
# Out:
#                     City  Index      Customer Id First Name  \
# 0       Lake Jeffborough      1  EB54EF1154C3A78    Heather
# 1             Aaronville      2  10dAcafEBbA5FcA   Kristina
# 2            East Jordan      3  67DAB15Ebe4BE4a     Briana
# 3            Andresmouth      5  5820deAdCF23EFe   Kathleen
# 4     Lake Madelineburgh      6  E1CDEaC63fDd5aA     Trevor
# ...                  ...    ...              ...        ...
# 9994          Petersport   9996  DD0caa06ebf217c     Meghan
# 9995          Briggsport   9997  C1C62ff90D0AfED   Jeremiah
# 9996      West Joyceport   9998  2EfAa6Fe435A7DA      Peggy
# 9997      Camachochester   9999  5dB06C3Fab5CCCb       Evan
# 9998          Sparkstown  10000  9903e8fF4D8Ff0F    Melissa
#
#                        Company                       Country  \
# 0                 Mosley-David                        Norway
# 1     Horn, Shepard and Watson                       Andorra
# ...

# %% [markdown]
# # Making a data frame from a Dictionary

# %%
d = {"key":[1,2,3,4,5],
       "key2":[6,7,8,9,10],
       "key3":[11,12,13,14,15]
      }

# %%
print(d)
# Out:
# {'key': [1, 2, 3, 4, 5], 'key2': [6, 7, 8, 9, 10], 'key3': [11, 12, 13, 14, 15]}

# %%
pd.DataFrame(d)
# Out:
#    key  key2  key3
# 0    1     6    11
# 1    2     7    12
# 2    3     8    13
# 3    4     9    14
# 4    5    10    15

# %%
df1 = pd.read_csv("")
